# %%
# !git clone https://github.com/kushalBanda/SeismoNet-4-1-Project-.git
# Out:
# Cloning into 'SeismoNet-4-1-Project-'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 44 (delta 0), reused 5 (delta 0), pack-reused 39
# Receiving objects: 100% (44/44), 219.86 MiB | 17.27 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (36/36), done.

# %%
# !python /content/SeismoNet-4-1-Project-/trainer.py --data_path /content/SeismoNet-4-1-Project-/saved_data
# Out:
# 2023-11-15 03:53:33.919601: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 03:53:33.919663: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 03:53:33.919707: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 03:53:33.929102: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python /content/SeismoNet-4-1-Project-/infer.py --best_model /content/best_model.pt --data_path /content/SeismoNet-4-1-Project-/saved_data --evaluate
